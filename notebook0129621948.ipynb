# %%
# !pip install -r requirements.txt

# %%
import shutil

# 复制文件到输出目录
shutil.copy("/kaggle/input/vitdemo/ViT_CIFAR100-(2023.12.14)/main.py", "main.py")

# %%
! python /kaggle/input/vitdemo/ViT_CIFAR100_Kaggle/main.py

# %%
# !ls

# %%
# !wget https://bin.equinox.io/c/4VmDzA7iaHb/ngrok-stable-linux-amd64.zip
# !unzip ngrok-stable-linux-amd64.zip
# !./ngrok authtoken  2ZnepBZiJijVHEF1ARBNFejI6Fr_7Tci3rVX4J1ELNGpexQ5k

# %%
import os
import multiprocessing

pool = multiprocessing.Pool(processes = 10)
results_of_processes = [pool.apply_async(os.system, args=(cmd, ), callback = None )
                        for cmd in [
                        f"tensorboard --logdir /kaggle/working/logs --host 0.0.0.0 --port 6006 &",
                        "./ngrok http 6006 &"
                        ]]

# %%
! curl -s http://localhost:4040/api/tunnels | python3 -c \
    "import sys, json; print(json.load(sys.stdin)['tunnels'][0]['public_url'])"

# %%
print("结束了哈哈")
# Out:
# 结束了哈哈
